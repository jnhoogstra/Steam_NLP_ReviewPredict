# %%
import requests
import pandas as pd

# %%
payload={'num_per_page': 100}
tom_call = requests.get('https://store.steampowered.com/appreviews/359550?json=1', params=payload)
tom_call.ok
# Out:
# True

# %%
tom = json.loads(call.text)

# %%
tom
# Out:
# {'success': 1,
#  'query_summary': {'num_reviews': 20,
#   'review_score': 8,
#   'review_score_desc': 'Very Positive',
#   'total_positive': 321676,
#   'total_negative': 37024,
#   'total_reviews': 358700},
#  'reviews': [{'recommendationid': '95231039',
#    'author': {'steamid': '76561198415401336',
#     'num_games_owned': 8,
#     'num_reviews': 1,
#     'playtime_forever': 29207,
#     'playtime_last_two_weeks': 1922,
#     'playtime_at_review': 24066,
#     'last_played': 1628188487},
#    'language': 'english',
# ...

# %%
tom.keys()
# Out:
# dict_keys(['success', 'query_summary', 'reviews', 'cursor'])

# %%
tom['query_summary']
# Out:
# {'num_reviews': 20,
#  'review_score': 8,
#  'review_score_desc': 'Very Positive',
#  'total_positive': 321676,
#  'total_negative': 37024,
#  'total_reviews': 358700}

# %%
tom['reviews'][1]['author']['steamid']
# Out:
# '76561198072032186'

# %%
tom['reviews'][1]['voted_up']
# Out:
# False

# %%
ids = []
for i in range(0,20):
    ids.append(tom['reviews'][i]['author']['steamid'])

# %%
ids
# Out:
# ['76561198415401336',
#  '76561198072032186',
#  '76561198388814970',
#  '76561198880901543',
#  '76561198854471815',
#  '76561197982148188',
#  '76561199062682154',
#  '76561198408769259',
#  '76561198809582456',
#  '76561198343143433',
#  '76561198335882876',
#  '76561198021516322',
#  '76561198834963698',
#  '76561198280178147',
#  '76561198846941223',
#  '76561198448518930',
#  '76561198370172350',
#  '76561198423313561',
#  '76561198008376294',
#  '76561199037848128']

# %%
voted_up = []
for i in range(0,20):
    voted_up.append(tom['reviews'][i]['voted_up'])

# %%
voted_up
# Out:
# [True,
#  False,
#  True,
#  True,
#  False,
#  False,
#  True,
#  True,
#  True,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False]
